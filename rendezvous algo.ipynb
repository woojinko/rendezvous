# %%
import googlemaps
import json
from datetime import datetime

# %%
gmaps = googlemaps.Client(key='AIzaSyAMA6Vw5X3pzhUxUPe_fPUrOXwVvpclxr0')

# %%
response = gmaps.places_nearby(location=(37.870944, -122.250722), rank_by="prominence", type='store', radius=500)
response
# Out:
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': 37.8696799,
#      'lng': -122.2520091},
#     'viewport': {'northeast': {'lat': 37.8710162802915,
#       'lng': -122.2507410197085},
#      'southwest': {'lat': 37.8683183197085, 'lng': -122.2534389802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#    'id': '9485d50ecc59572ed37f86567572edd747da5654',
#    'name': 'International House Cafe',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117829268923233058064/photos">Aymerick PENICAUT</a>'],
#      'photo_reference': 'CmRaAAAA1kKYgBvsrO5lNG5qTlMub1GgXnddoRQUhFCYrA9wRK_bpCnn7tzzcFXa9RovbAhkwuYy0EiV7YvoinAGbo4_eO3ZUlNhcjrNpucIgCoLIebOHuls6QY-1mEbyZzbSWSBEhCbW1uY7UVSl9SDklDkgbPVGhSStWvd_NCFNNzrd4GUoSWeiHDCxg',
#      'width': 3024}],
#    'place_id': 'ChIJaYHARDB8hYARRY9Kq7EU3q0',
# ...

# %%
name = response['results'][0]['name']
loc = response['results'][0]['geometry']['location']
lat, lon = loc['lat'], loc['lng']

# %%
name
# Out:
# 'International House Cafe'

# %%
def find_nearest(points):
    lat = sum([p[0] for p in points]) / len(points)
    lon = sum([p[1] for p in points]) / len(points)
    gmaps = googlemaps.Client(key='AIzaSyAMA6Vw5X3pzhUxUPe_fPUrOXwVvpclxr0')
    response = gmaps.places_nearby(location=(lat, lon), rank_by='distance', type="store")
    name = response['results'][0]['name']
    loc = response['results'][0]['geometry']['location']
    lat, lon = loc['lat'], loc['lng']
